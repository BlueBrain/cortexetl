# %%
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.append('../..')
import cortexetl as c_etl
import shared_functions as sf

outdir = "/gpfs/bbp.cscs.ch/project/proj83/home/isbister/spike_sorting_bias_output_data/comparison/"
import os; os.makedirs(outdir, exist_ok=True)

# %%
ground_ma = c_etl.analysis_initial_processing("/gpfs/bbp.cscs.ch/project/proj83/home/isbister/physiology_2023/cortexetl.configs/post_physiology_2023/campaigns/spikesorting_stimulus_tests/8_spikesorting_stimulus_test_neuropixels_13-4-24__8slc_100f_72r_250t_200ms_0.yaml") # , loglevel="ERROR"
ground_a = ground_ma.hex0_spikes

# sorted_ma = c_etl.analysis_initial_processing("/gpfs/bbp.cscs.ch/project/proj147/home/isbister/experimental_data/1_silico_spike_sorting/4_etl_converted/8_spikesorting_stimulus_test_neuropixels_13-4-24__8slc_100f_72r_250t_200ms_0/ss/analysis_config_cond_windows.yaml", create_figure_dirs=False) # loglevel="ERROR", 
# sorted_a = sorted_ma.array0
# Out:
# 2024-04-29 18:43:43,622 INFO blueetl.analysis: MultiAnalyzer configuration: /gpfs/bbp.cscs.ch/project/proj83/home/isbister/physiology_2023/cortexetl.configs/post_physiology_2023/campaigns/spikesorting_stimulus_tests/8_spikesorting_stimulus_test_neuropixels_13-4-24__8slc_100f_72r_250t_200ms_0.yaml
# 2024-04-29 18:43:43,742 INFO blueetl.store.base: Using class ParquetStore with basedir /gpfs/bbp.cscs.ch/project/proj83/home/isbister/post_physiology_2023/cortex_etl_output/campaigns/spikesorting_stimulus_tests/8_spikesorting_stimulus_test_neuropixels_13-4-24/8_spikesorting_stimulus_test_neuropixels_13-4-24__8slc_100f_72r_250t_200ms_0/hex0_spikes/repo
# 2024-04-29 18:43:43,742 INFO blueetl.store.base: Using class ParquetStore with basedir /gpfs/bbp.cscs.ch/project/proj83/home/isbister/post_physiology_2023/cortex_etl_output/campaigns/spikesorting_stimulus_tests/8_spikesorting_stimulus_test_neuropixels_13-4-24/8_spikesorting_stimulus_test_neuropixels_13-4-24__8slc_100f_72r_250t_200ms_0/hex0_spikes/features
# 2024-04-29 18:43:43,743 INFO blueetl.cache: Initialize cache
# 2024-04-29 18:43:43,743 INFO blueetl.cache: Invalidated cache: ['simulations', 'neurons', 'neuron_classes', 'trial_steps', 'windows', 'report', 'features']
# 2024-04-29 18:43:43,826 INFO blueetl.repository: Extracting simulations...
# 2024-04-29 18:43:43,832 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:43,837 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:43,841 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:43,845 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:43,931 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:43,936 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:43,940 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:43,945 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:43,949 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:43,953 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:43,957 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:43,961 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:43,981 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,043 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,068 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,106 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,174 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,219 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,312 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,336 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,360 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,380 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,401 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,417 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,437 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,459 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,483 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,499 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,516 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,535 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,552 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,577 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,600 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,646 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,664 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,681 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,695 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,708 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,719 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,732 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,755 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,795 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,814 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,842 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,856 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,880 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,899 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,932 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:44,986 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:45,018 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:45,064 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:45,099 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:45,119 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:45,138 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:45,212 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:45,230 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:45,256 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:45,278 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:45,315 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:45,340 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:45,454 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:45,479 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
# 2024-04-29 18:43:45,486 WARNING bluepy_configfile.configfile: Have keys ({'desired_connected_fr_L1I', 'desired_connected_fr_L5I', 'desired_connected_fr_L6I', 'desired_connected_fr_L23I', 'LFPWeightsPath', 'desired_unconnected_fr_L5E', 'desired_unconnected_fr_L5I', 'desired_unconnected_fr_L23E', 'desired_unconnected_fr_L23I', 'desired_connected_fr_L4I', 'desired_unconnected_fr_L6E', 'desired_unconnected_fr_L4I', 'desired_connected_fr_L4E', 'desired_connected_fr_L5E', 'desired_unconnected_fr_L1I', 'depol_stdev_mean_ratio', 'desired_connected_fr_L6E', 'desired_unconnected_fr_L6I', 'desired_connected_proportion_of_invivo_frs', 'desired_unconnected_fr_L4E', 'desired_connected_fr_L23E'}) that are not defined for section: Run
, 30800.0, 31000.0, 31200.0, 31400.0, 31600.0, 31800.0, 32000.0, 32200.0, 32400.0, 32600.0, 32800.0, 33000.0, 33200.0, 33400.0, 33600.0, 33800.0, 34000.0, 34200.0, 34400.0, 34600.0, 34800.0, 35000.0, 35200.0, 35400.0, 35600.0, 35800.0, 36000.0, 36200.0, 36400.0, 36600.0, 36800.0, 37000.0, 37200.0, 37400.0, 37600.0, 37800.0, 38000.0, 38200.0, 38400.0, 38600.0, 38800.0, 39000.0, 39200.0, 39400.0, 39600.0, 39800.0, 40000.0, 40200.0, 40400.0, 40600.0, 40800.0, 41000.0, 41200.0, 41400.0, 41600.0, 41800.0, 42000.0, 42200.0, 42400.0, 42600.0, 42800.0, 43000.0, 43200.0, 43400.0, 43600.0, 43800.0, 44000.0, 44200.0, 44400.0, 44600.0, 44800.0, 45000.0, 45200.0, 45400.0, 45600.0, 45800.0, 46000.0, 46200.0, 46400.0, 46600.0, 46800.0, 47000.0, 47200.0, 47400.0, 47600.0, 47800.0, 48000.0, 48200.0, 48400.0, 48600.0, 48800.0, 49000.0, 49200.0, 49400.0, 49600.0, 49800.0], t_start=-50.0, t_stop=250.0, t_step=0.0, duration=300.0
# 2024-04-29 18:43:56,910 INFO blueetl.cache: Writing cached windows
# 2024-04-29 18:43:56,923 INFO blueetl.repository: Extracting windows: cached=False, filtered=False
# 2024-04-29 18:43:56,924 INFO blueetl.repository: Extracting windows [done in 0.16 seconds]
# 2024-04-29 18:43:56,924 INFO blueetl.repository: Extracting report...
# [Parallel(n_jobs=36)]: Using backend LokyBackend with 36 concurrent workers.
# 2024-04-29 18:43:56,961 INFO blueetl.parallel: Considering 12 rows for columns ['simulation_id', 'circuit_id']
# 2024-04-29 18:43:56,965 INFO blueetl.parallel: Tasks to be executed: 12
# [Parallel(n_jobs=36)]: Done   1 tasks      | elapsed:   51.7s
# [Parallel(n_jobs=36)]: Done   3 out of  12 | elapsed:   54.6s remaining:  2.7min
# [Parallel(n_jobs=36)]: Done   5 out of  12 | elapsed:   57.5s remaining:  1.3min
# [Parallel(n_jobs=36)]: Done   7 out of  12 | elapsed:  1.0min remaining:   43.3s
# [Parallel(n_jobs=36)]: Done   9 out of  12 | elapsed:  1.1min remaining:   21.2s
# [Parallel(n_jobs=36)]: Done  12 out of  12 | elapsed:  1.1min finished
# 2024-04-29 18:45:35,421 INFO blueetl.cache: Writing cached report
# 2024-04-29 18:45:59,951 INFO blueetl.repository: Extracting report: cached=False, filtered=False
# 2024-04-29 18:45:59,952 INFO blueetl.repository: Extracting report [done in 123.03 seconds]
# 2024-04-29 18:45:59,953 INFO blueetl.features: Step 1: grouping features by attributes...
# 2024-04-29 18:45:59,953 INFO blueetl.features: Preprocessing features 1/1 [id=0]
# 2024-04-29 18:45:59,954 INFO blueetl.features: Step 1: grouping features by attributes [done in 0.00 seconds]
# 2024-04-29 18:45:59,954 INFO blueetl.features: Step 2: processing cached features...
# 2024-04-29 18:45:59,955 INFO blueetl.features: Step 2: processing cached features [done in 0.00 seconds]
# 2024-04-29 18:45:59,955 INFO blueetl.features: Step 3: processing new features...
# 2024-04-29 18:45:59,955 INFO blueetl.features: Considering group: 1/1, key: FeaturesConfigKey(groupby=['simulation_id', 'circuit_id', 'neuron_class', 'window'], neuron_classes=[], windows=[])
# [Parallel(n_jobs=36)]: Using backend LokyBackend with 36 concurrent workers.
# 2024-04-29 18:45:59,965 INFO blueetl.parallel: Considering 25 rows for columns ['circuit_id', 'neuron_class']
# 2024-04-29 18:45:59,967 INFO blueetl.parallel: Considering 96 rows for columns ['simulation_id', 'circuit_id', 'window']
# 2024-04-29 18:45:59,973 INFO blueetl.parallel: Tasks to be executed: 2400
# [Parallel(n_jobs=36)]: Done  13 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=36)]: Done  26 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=36)]: Done  41 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=36)]: Done  56 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=36)]: Done  73 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=36)]: Done  90 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=36)]: Done 109 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=36)]: Done 128 tasks      | elapsed:   13.2s
# [Parallel(n_jobs=36)]: Done 149 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=36)]: Done 170 tasks      | elapsed:   14.6s
# [Parallel(n_jobs=36)]: Done 193 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=36)]: Done 216 tasks      | elapsed:   18.0s
# [Parallel(n_jobs=36)]: Done 241 tasks      | elapsed:   20.4s
# [Parallel(n_jobs=36)]: Done 266 tasks      | elapsed:   22.6s
# [Parallel(n_jobs=36)]: Done 293 tasks      | elapsed:   25.1s
# [Parallel(n_jobs=36)]: Done 320 tasks      | elapsed:   27.4s
# [Parallel(n_jobs=36)]: Done 349 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=36)]: Done 378 tasks      | elapsed:   35.3s
# [Parallel(n_jobs=36)]: Done 409 tasks      | elapsed:   36.8s
# [Parallel(n_jobs=36)]: Done 440 tasks      | elapsed:   38.3s
# [Parallel(n_jobs=36)]: Done 473 tasks      | elapsed:   39.5s
# [Parallel(n_jobs=36)]: Done 506 tasks      | elapsed:   43.6s
# [Parallel(n_jobs=36)]: Done 541 tasks      | elapsed:   44.7s
# [Parallel(n_jobs=36)]: Done 576 tasks      | elapsed:   45.9s
# [Parallel(n_jobs=36)]: Done 613 tasks      | elapsed:   50.4s
# [Parallel(n_jobs=36)]: Done 650 tasks      | elapsed:   57.4s
# [Parallel(n_jobs=36)]: Done 689 tasks      | elapsed:   59.6s
# [Parallel(n_jobs=36)]: Done 728 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=36)]: Done 769 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=36)]: Done 810 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=36)]: Done 853 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=36)]: Done 896 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=36)]: Done 941 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=36)]: Done 986 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=36)]: Done 1033 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=36)]: Done 1080 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=36)]: Done 1129 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=36)]: Done 1178 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=36)]: Done 1229 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=36)]: Done 1280 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=36)]: Done 1333 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=36)]: Done 1386 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=36)]: Done 1441 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=36)]: Done 1496 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=36)]: Done 1553 tasks      | elapsed:  2.2min
# /gpfs/bbp.cscs.ch/home/isbister/cortexetl.jupyter_04_01_23/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [Parallel(n_jobs=36)]: Done 1610 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=36)]: Done 1669 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=36)]: Done 1728 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=36)]: Done 1789 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=36)]: Done 1850 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=36)]: Done 1913 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=36)]: Done 1976 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=36)]: Done 2041 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=36)]: Done 2106 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=36)]: Done 2173 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=36)]: Done 2240 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=36)]: Done 2309 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=36)]: Done 2400 out of 2400 | elapsed:  3.5min finished
# 2024-04-29 18:57:09,380 INFO blueetl.cache: Writing cached features
# 2024-04-29 19:02:19,428 INFO blueetl.features: Calculated features 1/1 [id=0]
# - by_gid: cached=False, filtered=False
# - by_gid_and_trial: cached=False, filtered=False
# - by_neuron_class: cached=False, filtered=False
# - by_neuron_class_and_trial: cached=False, filtered=False
# - histograms: cached=False, filtered=False
# 2024-04-29 19:02:19,428 INFO blueetl.features: Step 3: processing new features [done in 979.47 seconds]
# 2024-04-29 19:02:19,429 INFO blueetl.features: Features calculation completed

# %%
label = "ground_truth"
a = ground_a
window="evoked_SOZ_100ms"
nc = "ALL"
# n_gid_spikes_plot_tresh = 150
n_gid_spikes_plot_tresh = 100
plot_tresh_prop_non_first = 1.0

# label = "kilosort3"
# a = sorted_a
# window = "Cond0_0_100ms_stim"
# nc = "array0"
# plot_tresh_n_gid_spikes = 50
# plot_tresh_prop_non_first = 1.0

filenames = []
for sim_ind in [0]:
    
    window_by_gid_and_trial = a.features.by_gid_and_trial.df.reset_index().etl.q(simulation_id=sim_ind, window=window, neuron_class=nc)
    spikes_df = a.repo.report.df.etl.q(simulation_id=sim_ind, window=window, neuron_class=nc)

    
#     plt.figure()
    # plt.hist(window_by_gid_and_trial['count'][window_by_gid_and_trial['count'] != 0], bins=[-0.1, 0.9, 1.9, 2.9])
#     plt.hist(window_by_gid_and_trial['count'], bins=[0.9, 1.9, 2.9])
#     plt.show()

    cs = np.asarray(['k', 'r', 'b', 'g', 'cyan', 'orange', 'yellow', 'grey', 'grey', 'grey', 'grey', 'grey', 'grey', 'grey', 'grey'])
    n_all_vs_firsts = []

    single_gid_images = []
    for gid in window_by_gid_and_trial.gid.unique():
#         print(gid)
        
        gid_window_by_gid_and_trial = window_by_gid_and_trial.etl.q(gid=gid)

        if np.sum(~gid_window_by_gid_and_trial["first"].isna()):

            gid_spikes = spikes_df.etl.q(gid=gid).copy()
            first_spikes_df = gid_window_by_gid_and_trial[~gid_window_by_gid_and_trial["first"].isna()]
            first_spikes_t = first_spikes_df["first"]

            n_gid_spikes = len(gid_spikes)
            n_first_spikes = len(first_spikes_t)

            n_all_vs_firsts.append([n_gid_spikes, n_first_spikes])

            do_plot = True
            if do_plot & (n_gid_spikes > plot_tresh_prop_non_first*n_first_spikes) & (n_gid_spikes > plot_tresh_n_gid_spikes):

                fig, axes = plt.subplots(2, 2, figsize=(4, 4))
                
                gid_spikes['order'] = np.concatenate([range(i) for i in gid_spikes.groupby(["trial"])["time"].count()])
                gid_spikes['c'] = cs[gid_spikes['order']]
                axes[0][0].scatter(gid_spikes.time, gid_spikes.trial, s=.5, c=gid_spikes.c)
                axes[0][1].scatter(first_spikes_t, first_spikes_df.trial, s=.5)
                axes[1][0].hist(gid_spikes.time, bins=range(0, 100, 4))
                axes[1][1].hist(first_spikes_t, bins=range(0, 100, 4))

                axes[0][0].set_xlim([0, 100])
                axes[0][1].set_xlim([0, 100])
                axes[1][0].set_xlim([0, 100])
                axes[1][1].set_xlim([0, 100])
                
                axes[0][0].set_xlabel('Time (ms)')
                axes[0][1].set_xlabel('Time (ms)')
                axes[1][0].set_xlabel('Time (ms)')
                axes[1][1].set_xlabel('Time (ms)')
                
                axes[0][0].set_ylabel('Trial')
                axes[0][1].set_ylabel('Trial')
                axes[1][0].set_ylabel('Freq')
                axes[1][1].set_ylabel('Freq')
                
                axes[0][0].set_title('All spikes')
                axes[0][1].set_title('First spikes')
                
                filename = 'temp_images/' + str(gid) + '.png'
                filenames.append(filename)
                plt.savefig(filename)
                plt.show()
                plt.close()
                
    n_all_vs_firsts = np.asarray(n_all_vs_firsts)
    plt.figure()
    plt.scatter(n_all_vs_firsts[:, 1], n_all_vs_firsts[:, 0], s=.1)
    plt.gca().set_xlim([0, 200])
    plt.gca().set_ylim([0, 200])
    plt.savefig(str(sim_ind) + '_first_vs_all.pdf')
    plt.show()
    plt.close()


    plt.figure()
    plt.hist(n_all_vs_firsts[:, 1]/n_all_vs_firsts[:, 0], np.arange(0, 0.99, 0.09))
    plt.savefig(str(sim_ind) + '_first_div_all.pdf')
    plt.show()
    plt.close()
    
c_etl.video_from_image_files(filenames, label + ".mp4", delete_images=True)

# %%
# !grep -r spikewarp ../../cortexetl.

# %%
# !python ../../run.py /gpfs/bbp.cscs.ch/project/proj83/home/isbister/physiology_2023/cortexetl.configs/post_physiology_2023/campaigns/spikesorting_stimulus_tests/6_spikesorting_stimulus_test_neuropixels_17-3-24__8slc_80f_5r_100t_200ms_0.yaml
