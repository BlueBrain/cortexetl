# %%
l4_x = [19.78990648, 213.6265286, 407.6345379, 601.2462916, 796.6857084, 989.9970615, 1184.757841, 1378.764781]
l4_y = [0.028842076, 0.012562934, 0.012469383, 0.00737304, 0.007891097, 0.005586563, 0.006508453, 0.003055662]

l5a_x = [20.36273279, 214.2717604, 407.3571754, 600.1892534, 796.7903672, 989.54716, 1182.463903, 1377.817914]
l5b_y = [0.01621402, 0.019166697, 0.014721992, 0.012219882, 0.009733859, 0.009673122, 0.006916537, 0.005968691]

l5b6_x = [21.54894894, 211.3747173, 410.3374849, 601.5321288, 795.706753, 992.9814849, 1183.6451, 1376.621249]
l5b6_y = [0.02417641, 0.022232103, 0.021481386, 0.018351608, 0.010872922, 0.01233645, 0.010344227, 0.008394578]

# %%
import matplotlib.pyplot as plt

# Plot the data
plt.figure()
plt.plot(l4_x, l4_y, label="L4", c='black')
plt.plot(l5a_x, l5b_y, label="L5a", c='red')
plt.plot(l5b6_x, l5b6_y, label="L5b/6", c='blue')
plt.legend()

# Get current axis
ax = plt.gca()

# Set axis labels
ax.set_ylabel("Correlation coefficient")
ax.set_xlabel("Distance (um)")

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Set x-axis limits automatically
ax.set_xlim([0, 1400])
ax.set_ylim([0.0, 0.03])

# # Set major ticks to only the min and max of the data range
# ax.set_xticks([ax.get_xlim()[0], ax.get_xlim()[1]])
# ax.set_yticks([ax.get_ylim()[0], ax.get_ylim()[1]])

# Add minor ticks
ax.minorticks_on()

# Show the plot
plt.savefig('vivo_corr_dist_depen.pdf')
plt.show()
