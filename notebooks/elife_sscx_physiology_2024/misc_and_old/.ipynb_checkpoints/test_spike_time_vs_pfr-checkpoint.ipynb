# %%
import sys
sys.path.append('..')
import cortex_etl as c_etl
ma = c_etl.analysis_initial_processing("/gpfs/bbp.cscs.ch/project/proj83/home/isbister/physiology_2023/cortex_etl/configs/sscx_post_physiology/0-IC-IntialTest/0-IC-IntialTest-T1.yaml")

# %%
a = ma.hex0_spikes
a_name = "hex0_spikes"
ma.analyzers[a_name]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# neuron_class = "L5_INH"
window_features_by_gid_and_trial = a.features.by_gid_and_trial.df.reset_index().etl.q(window='evoked_SOZ_25ms', neuron_class=c_etl.LAYER_EI_NEURON_CLASSES[:-1])
window_features_by_gid = a.features.by_gid.df.reset_index().etl.q(window='evoked_SOZ_25ms', neuron_class=c_etl.LAYER_EI_NEURON_CLASSES[:-1])

window_features_by_gid_and_trial = pd.merge(window_features_by_gid_and_trial, a.repo.simulations.df, on='simulation_id')
window_features_by_gid = pd.merge(window_features_by_gid, a.repo.simulations.df, on='simulation_id')

# %%
import numpy as np



def plot_ordered_mean_fst(a):

    fig, axes = plt.subplots(ncols=5, nrows=2, figsize=(15, 3), sharex=True) #  sharey=True, 
    for col_i, neuron_class_grouping in enumerate(c_etl.LAYER_EI_NEURON_CLASS_GROUPINGS[:-1]):
        for row_i, neuron_class in enumerate(neuron_class_grouping):
            if (neuron_class == "L1_INH"): 
                row_i = 1
            ax = axes[row_i][col_i]
            window_nc_features_by_gid = window_features_by_gid.etl.q(neuron_class=neuron_class)
            for ind, simulation_row in a.repo.simulations.df.iterrows():  
                test_df = window_nc_features_by_gid.etl.q({"simulation_id": simulation_row['simulation_id'], "mean_spike_counts": {"ge": 0.2}})
                mean_FSTs = np.asarray(test_df['first_spike_time_means_cort_zeroed'])
                ax.scatter(mean_FSTs[np.argsort(mean_FSTs)], test_df['neuron_class_index'], s=.1)
            if (row_i == 1): ax.set_xlabel('Time (ms)')
            ax.set_title(neuron_class)
    plt.show()
    

    
def plot_pfr_vs_mean_fst(a, pfrs):
    fig, axes = plt.subplots(ncols=5, nrows=2, figsize=(15, 3), sharex=True, sharey=True) #   
    for col_i, neuron_class_grouping in enumerate(c_etl.LAYER_EI_NEURON_CLASS_GROUPINGS[:-1]):
        for row_i, neuron_class in enumerate(neuron_class_grouping):
            if (neuron_class == "L1_INH"): 
                row_i = 1
            ax = axes[row_i][col_i]
            window_nc_features_by_gid = window_features_by_gid.etl.q(neuron_class=neuron_class)
            
            thresholded_window_nc_features_by_gid = window_nc_features_by_gid.etl.q({"desired_connected_proportion_of_invivo_frs": pfrs, "mean_spike_counts": {"ge": 0.2}})
            
            for neuron_class_index in thresholded_window_nc_features_by_gid.neuron_class_index.unique():
                test_df = window_nc_features_by_gid.etl.q(desired_connected_proportion_of_invivo_frs=pfrs, neuron_class_index=neuron_class_index)
                ax.plot(test_df['first_spike_time_means_cort_zeroed'], pfrs, lw=0.1)
    
            thresholded_pfr_means = thresholded_window_nc_features_by_gid.groupby(['desired_connected_proportion_of_invivo_frs']).mean(['first_spike_time_means_cort_zeroed'])['first_spike_time_means_cort_zeroed']
            ax.plot(thresholded_pfr_means, thresholded_pfr_means.reset_index().desired_connected_proportion_of_invivo_frs.unique(), lw=1)

            ax.set_xlabel('Time (ms)')
            ax.set_ylabel('$P_{FR}$')
    plt.show()
    
def scatter_2pfr_mean_fsts(a, pfrs):
    
    fig, axes = plt.subplots(ncols=5, nrows=2, figsize=(15, 3), sharex=True, sharey=True) #   
    for col_i, neuron_class_grouping in enumerate(c_etl.LAYER_EI_NEURON_CLASS_GROUPINGS[:-1]):
        for row_i, neuron_class in enumerate(neuron_class_grouping):
            if (neuron_class == "L1_INH"): 
                row_i = 1
            ax = axes[row_i][col_i]
            window_nc_features_by_gid = window_features_by_gid.etl.q(neuron_class=neuron_class)
            
            thresholded_window_nc_features_by_gid = window_nc_features_by_gid.etl.q({"desired_connected_proportion_of_invivo_frs": pfrs, "mean_spike_counts": {"ge": 0.2}})
    
            a = thresholded_window_nc_features_by_gid.etl.q(desired_connected_proportion_of_invivo_frs=pfrs[0])
            b = thresholded_window_nc_features_by_gid.etl.q(desired_connected_proportion_of_invivo_frs=pfrs[1])

            intersecting_gids = np.intersect1d(a.gid, b.gid)
            ax.scatter(a.etl.q(gid=intersecting_gids)['first_spike_time_means_cort_zeroed'], b.etl.q(gid=intersecting_gids)['first_spike_time_means_cort_zeroed'], s=0.1)
            ax.plot([5.0, 25.0], [5.0, 25.0], c='k', ls='--', lw=.2)
            if (row_i == 1): ax.set_xlabel('Time (ms)')
            ax.set_ylabel('Time (ms)')
            ax.set_title(neuron_class)

#             plt.figure()
#             plt.hist(a.etl.q(gid=intersecting_gids)['first_spike_time_means_cort_zeroed'].values - b.etl.q(gid=intersecting_gids)['first_spike_time_means_cort_zeroed'].values)
#             plt.show()
    
    

    
plot_ordered_mean_fst(a)
plot_pfr_vs_mean_fst(a, [0.1, 0.3, 0.5])
scatter_2pfr_mean_fsts(a, [0.1, 0.5])

# %%
soma_ma = c_etl.analysis_initial_processing("../configs/6-O1-MPScan/6-O1-MPScan-0-5x3x2-2sims.yaml") #, loglevel="ERROR
# Out:
# 2023-05-03 14:27:48,717 INFO blueetl.config.simulations: Detected xarray configuration format
# ---------------------------------------------------------------------------
# CacheError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 soma_ma = c_etl.analysis_initial_processing("../configs/6-O1-MPScan/6-O1-MPScan-0-5x3x2-2sims.yaml") #, loglevel="ERROR
#
# File /gpfs/bbp.cscs.ch/project/proj83/home/isbister/physiology_2023/cortex_etl/notebooks/../cortex_etl/manager.py:24, in analysis_initial_processing(analysis_config_file, loglevel)
#      16 def analysis_initial_processing(analysis_config_file, loglevel="INFO"):
#      18 	sns.set(style="ticks", context="paper", font="Helvetica Neue",
#      19         rc={"axes.labelsize": 7, "legend.fontsize": 6, "axes.linewidth": 0.6, "xtick.labelsize": 6, "ytick.labelsize": 6,
#      20             "xtick.major.size": 2, "xtick.major.width": 0.5, "xtick.minor.size": 1.5, "xtick.minor.width": 0.3,
#      21             "ytick.major.size": 2, "ytick.major.width": 0.5, "ytick.minor.size": 1.5, "ytick.minor.width": 0.3,
#      22             "axes.titlesize": 7, "axes.spines.right": False, "axes.spines.top": False})
# ---> 24 	ma = run_from_file(analysis_config_file, loglevel=loglevel)
#      25 	ma = ma.apply_filter()
#      27 	for a in ma.analyzers.values():
#
# File ~/cortex_etl_jupyter_04_01_23/lib/python3.10/site-packages/blueetl/analysis.py:337, in run_from_file(analysis_config_file, seed, extract, calculate, show, clear_cache, loglevel)
#     335 if seed is not None:
#     336     np.random.seed(seed)
# --> 337 ma = MultiAnalyzer.from_file(analysis_config_file, clear_cache=clear_cache)
#     338 if extract:
#     339     ma.extract_repo()
#
# File ~/cortex_etl_jupyter_04_01_23/lib/python3.10/site-packages/blueetl/analysis.py:208, in MultiAnalyzer.from_file(cls, path, clear_cache)
#     205 @classmethod
#     206 def from_file(cls, path: StrOrPath, clear_cache: Optional[bool] = None) -> "MultiAnalyzer":
#     207     """Return a new instance loaded using the given configuration file."""
# --> 208     return cls(
#     209         global_config=load_yaml(path),
#     210         base_path=Path(path).parent,
#     211         clear_cache=clear_cache,
#     212     )
#
# File ~/cortex_etl_jupyter_04_01_23/lib/python3.10/site-packages/blueetl/analysis.py:187, in MultiAnalyzer.__init__(self, global_config, base_path, clear_cache, _analyzers)
#     185     if clear_cache is None:
#     186         clear_cache = self._global_config.clear_cache
# --> 187     self._analyzers = self._init_analyzers(clear_cache=clear_cache)
#     188 else:
#     189     self._analyzers = _analyzers
#
# File ~/cortex_etl_jupyter_04_01_23/lib/python3.10/site-packages/blueetl/analysis.py:195, in MultiAnalyzer._init_analyzers(self, clear_cache)
#     193 resolver = AttrResolver(self)
#     194 simulations_config = SimulationsConfig.load(self.global_config.simulation_campaign)
# --> 195 return {
#     196     name: Analyzer(
#     197         analysis_config=analysis_config,
#     198         simulations_config=simulations_config,
#     199         resolver=resolver,
#     200         clear_cache=clear_cache,
#     201     )
#     202     for name, analysis_config in self.global_config.analysis.items()
#     203 }
#
# File ~/cortex_etl_jupyter_04_01_23/lib/python3.10/site-packages/blueetl/analysis.py:196, in <dictcomp>(.0)
#     193 resolver = AttrResolver(self)
#     194 simulations_config = SimulationsConfig.load(self.global_config.simulation_campaign)
#     195 return {
# --> 196     name: Analyzer(
#     197         analysis_config=analysis_config,
#     198         simulations_config=simulations_config,
#     199         resolver=resolver,
#     200         clear_cache=clear_cache,
#     201     )
#     202     for name, analysis_config in self.global_config.analysis.items()
#     203 }
#
# File ~/cortex_etl_jupyter_04_01_23/lib/python3.10/site-packages/blueetl/analysis.py:53, in Analyzer.__init__(self, analysis_config, simulations_config, resolver, clear_cache, _repo, _features)
#      51 else:
#      52     assert simulations_config is not None
# ---> 53     cache_manager = CacheManager(
#      54         analysis_config=analysis_config,
#      55         simulations_config=simulations_config,
#      56         clear_cache=clear_cache,
#      57     )
#      58     self._repo = Repository(
#      59         simulations_config=simulations_config,
#      60         extraction_config=analysis_config.extraction,
#    (...)
#      63         resolver=resolver,
#      64     )
#      65     self._features = FeaturesCollection(
#      66         features_configs=analysis_config.features,
#      67         repo=self.repo,
#      68         cache_manager=cache_manager,
#      69     )
#
# File ~/cortex_etl_jupyter_04_01_23/lib/python3.10/site-packages/blueetl/cache.py:126, in CacheManager.__init__(self, analysis_config, simulations_config, store_class, clear_cache)
#     123     new_dir.mkdir(exist_ok=True, parents=True)
#     125 self._lock_manager = LockManager(self._output_dir)
# --> 126 self._lock_manager.lock()
#     128 self.readonly = False
#     129 self._version = 1
#
# File ~/cortex_etl_jupyter_04_01_23/lib/python3.10/site-packages/blueetl/cache.py:87, in LockManager.lock(self)
#      85 os.close(self._fd)
#      86 self._fd = None
# ---> 87 raise CacheError(f"Another process is locking {self._path}") from None
#
# CacheError: Another process is locking /gpfs/bbp.cscs.ch/project/proj83/home/isbister/physiology_2023/cortex_etl_output/6-O1-MPScan/6-O1-MPScan-0-5x3x2-2sims/soma

# %%
# def MeanFSTOrdering2(simulations):
#     plt.figure()
#     initial_ordering = []
#     for ind, simulation_row in simulations[::-1].iterrows():    
#         test_df = window_nc_features_by_gid.etl.q({"simulation_id": simulation_row['simulation_id'], "mean_spike_counts": {"ge": 0.4}})
# #         test_df = window_nc_features_by_gid.etl.q(simulation_id=simulation_row['simulation_id'])
#         plt.gca().set_title(simulation_row['simulation_string'])
#         mean_FSTs = np.asarray(test_df['first_spike_time_means_cort_zeroed'])
#         if (len(initial_ordering) == 0):
#             initial_ordering  = np.argsort(mean_FSTs)
#         plt.scatter(mean_FSTs[initial_ordering], range(len(initial_ordering)), s=.1)
#     plt.show()
    
# MeanFSTOrdering2(test_sims)
#     test_df = window_nc_features_by_gid_and_trial.etl.q(simulation_id=simulation_row['simulation_id'])
#     plt.figure()
#     plt.gca().set_title(simulation_row['simulation_string'])
#     plt.scatter(test_df['first'], test_df['neuron_class_index'], s=.1)
#     plt.gca().set_xlim([10.0, 25.0])
#     plt.show()
    
#     if (ind > 0):
#         break
