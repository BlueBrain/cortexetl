# %%
import sys
sys.path.append('../../../../..')
import cortex_etl as c_etl

# %%
# ma = c_etl.analysis_initial_processing("stage_2_or_3_connection_x.yaml", loglevel="ERROR") #
ma = c_etl.analysis_initial_processing("connectome_rewiring_calibration_example.yaml") # loglevel="ERROR"
a_hex0 = ma.hex0_spikes
a_hexO1 = ma.hex_O1_spikes

# %%
c_etl.post_analysis(a_hex0)
# Out:
# ----- Custom post analysis -----
# [Parallel(n_jobs=36)]: Using backend LokyBackend with 36 concurrent workers.
# 2023-11-08 15:56:20,609 INFO blueetl.parallel: Considering 10 rows for columns ['simulation_id', 'circuit_id']
# 2023-11-08 15:56:20,612 INFO blueetl.parallel: Tasks to be executed: 10
# [Parallel(n_jobs=36)]: Done   3 out of  10 | elapsed:    4.4s remaining:   10.2s
# [Parallel(n_jobs=36)]: Done   5 out of  10 | elapsed:    4.4s remaining:    4.4s
# [Parallel(n_jobs=36)]: Done   7 out of  10 | elapsed:    4.4s remaining:    1.9s
# [Parallel(n_jobs=36)]: Done  10 out of  10 | elapsed:    4.4s finished
# [Parallel(n_jobs=36)]: Using backend LokyBackend with 36 concurrent workers.
# 2023-11-08 15:56:26,754 INFO blueetl.parallel: Considering 10 rows for columns ['simulation_id', 'circuit_id']
# 2023-11-08 15:56:26,757 INFO blueetl.parallel: Tasks to be executed: 10
# ----- Custom post analysis complete: 8.95s -----
# [Parallel(n_jobs=36)]: Done   3 out of  10 | elapsed:    2.2s remaining:    5.0s
# [Parallel(n_jobs=36)]: Done   5 out of  10 | elapsed:    2.2s remaining:    2.2s
# [Parallel(n_jobs=36)]: Done   7 out of  10 | elapsed:    2.2s remaining:    0.9s
# [Parallel(n_jobs=36)]: Done  10 out of  10 | elapsed:    2.2s finished

# %%
c_etl.plot_multi_sim_analysis(a_hex0)
# Out:
# ----- Plot firing rates, proportions and predictions -----
# ['unconn_2nd_half', 'conn_spont']
# ['desired_connected_fr', 'conn_spont']
# ['desired_unconnected_fr', 'unconn_2nd_half']
# ['connection_fr_increase', 'connection_fr_error']
# ['unconn_2nd_half', 'conn_spont']
# ['desired_connected_fr', 'conn_spont']
# ['desired_unconnected_fr', 'unconn_2nd_half']
# ['connection_fr_increase', 'connection_fr_error']
# ['unconn_2nd_half', 'conn_spont']
# ['desired_connected_fr', 'conn_spont']
# ['desired_unconnected_fr', 'unconn_2nd_half']
# ['connection_fr_increase', 'connection_fr_error']
# ----- Plot meta heatmaps -----
# Create heatmap: neuron_group_gt_threshold_fr
# Create heatmap: simulation_id
# Create heatmap: bursting
# Create heatmap: bursting_ratio
# Create heatmap: bursting_or_fr_gt_threshold
# Create heatmap: ei_corr_rval
# Create heatmap: ei_corr_rval
# Create heatmap: ei_corr_rval
# Create heatmap: ei_corr_rval
# Create heatmap: mean_of_mean_firing_rates_per_second
# Create heatmap: mean_of_mean_firing_rates_per_second
# Create heatmap: log_mean_of_mean_firing_rates_per_second
# Create heatmap: log_mean_of_mean_firing_rates_per_second
# Create heatmap: power
# Create heatmap: power
# Create heatmap: power
# Create heatmap: power
# ----- Plot meta lineplots -----
# Create lineplot: mean_of_mean_firing_rates_per_second
# Create lineplot: mean_of_mean_firing_rates_per_second
# Create lineplot: log_mean_of_mean_firing_rates_per_second
# Create lineplot: log_mean_of_mean_firing_rates_per_second
# Create lineplot: ei_corr_rval
# Create lineplot: ei_corr_rval
# Create lineplot: std_of_neuron_class_proportions_of_vivo
# Create lineplot: cv_of_neuron_class_proportions_of_vivo
# Create lineplot: euc_dist_to_desired_proportion_of_in_vivo_FRs
# Create lineplot: euc_dist_to_scaled_in_vivo_FRs
# Create lineplot: difference_between_mean_proportion_and_target_proportion
# Create lineplot: ei_corr_rval
# Create lineplot: std_of_neuron_class_proportions_of_vivo
# Create lineplot: cv_of_neuron_class_proportions_of_vivo
# Create lineplot: euc_dist_to_desired_proportion_of_in_vivo_FRs
# Create lineplot: euc_dist_to_scaled_in_vivo_FRs
# Create lineplot: difference_between_mean_proportion_and_target_proportion
# Create lineplot: ei_corr_rval
# Create lineplot: std_of_neuron_class_proportions_of_vivo
# Create lineplot: cv_of_neuron_class_proportions_of_vivo
# Create lineplot: euc_dist_to_desired_proportion_of_in_vivo_FRs
# Create lineplot: euc_dist_to_scaled_in_vivo_FRs
# Create lineplot: difference_between_mean_proportion_and_target_proportion
#
# ----- Plot parameter effects -----
# Custom post analysis:  7
# Custom post analysis:  6
# Custom post analysis:  8
# Custom post analysis:  5
# Custom post analysis:  9
# Custom post analysis:  4
# Custom post analysis:  2
# Custom post analysis:  3
# Custom post analysis:  0
# Custom post analysis:  1

# %%
c_etl.plot_rasters(a_hex0)
# Out:
# ----- Plot rasters, window: conn_spont -----
# [Parallel(n_jobs=36)]: Using backend LokyBackend with 36 concurrent workers.
# 2023-11-08 16:02:21,785 INFO blueetl.parallel: Considering 10 rows for columns ['simulation_id', 'circuit_id']
# 2023-11-08 16:02:21,789 INFO blueetl.parallel: Tasks to be executed: 10
# [Parallel(n_jobs=36)]: Done   3 out of  10 | elapsed:   10.9s remaining:   25.5s
# [Parallel(n_jobs=36)]: Done   5 out of  10 | elapsed:   12.9s remaining:   12.9s
# [Parallel(n_jobs=36)]: Done   7 out of  10 | elapsed:   20.6s remaining:    8.8s
# [Parallel(n_jobs=36)]: Done  10 out of  10 | elapsed:   24.7s finished
# [Parallel(n_jobs=36)]: Using backend LokyBackend with 36 concurrent workers.
# 2023-11-08 16:02:46,854 INFO blueetl.parallel: Considering 10 rows for columns ['simulation_id', 'circuit_id']
# 2023-11-08 16:02:46,856 INFO blueetl.parallel: Tasks to be executed: 10
# [Parallel(n_jobs=36)]: Done   3 out of  10 | elapsed:    4.1s remaining:    9.5s
# [Parallel(n_jobs=36)]: Done   5 out of  10 | elapsed:    4.1s remaining:    4.1s
# [Parallel(n_jobs=36)]: Done   7 out of  10 | elapsed:    4.1s remaining:    1.8s
# [Parallel(n_jobs=36)]: Done  10 out of  10 | elapsed:    4.2s finished
# [Parallel(n_jobs=36)]: Using backend LokyBackend with 36 concurrent workers.
# 2023-11-08 16:02:51,470 INFO blueetl.parallel: Considering 10 rows for columns ['simulation_id', 'circuit_id']
# 2023-11-08 16:02:51,472 INFO blueetl.parallel: Tasks to be executed: 10
# [Parallel(n_jobs=36)]: Done   3 out of  10 | elapsed:    4.6s remaining:   10.7s
# [Parallel(n_jobs=36)]: Done   5 out of  10 | elapsed:    4.7s remaining:    4.7s
# [Parallel(n_jobs=36)]: Done   7 out of  10 | elapsed:    4.7s remaining:    2.0s
# [Parallel(n_jobs=36)]: Done  10 out of  10 | elapsed:    4.8s finished
# [Parallel(n_jobs=36)]: Using backend LokyBackend with 36 concurrent workers.
# 2023-11-08 16:02:56,690 INFO blueetl.parallel: Considering 10 rows for columns ['simulation_id', 'circuit_id']
# 2023-11-08 16:02:56,692 INFO blueetl.parallel: Tasks to be executed: 10
# [Parallel(n_jobs=36)]: Done   3 out of  10 | elapsed:    1.0s remaining:    2.3s
# [Parallel(n_jobs=36)]: Done   5 out of  10 | elapsed:    4.2s remaining:    4.2s
# [Parallel(n_jobs=36)]: Done   7 out of  10 | elapsed:    4.3s remaining:    1.8s
# [Parallel(n_jobs=36)]: Done  10 out of  10 | elapsed:    4.3s finished
# ----- Create raster videos, window: conn_spont -----

# %%
c_etl.extract_fr_df(a_hex0)
# Out:
# Raster generated:  5.66 s
# Raster generated:  9.81 s
# Raster generated:  13.43 s
# Raster generated:  15.08 s
# Raster generated:  16.85 s
# Raster generated:  17.21 s
# Raster generated:  0.64 s
# Raster generated:  0.65 s
# Raster generated:  0.59 s
# Raster generated:  0.57 s
# Raster generated:  0.63 s
# Raster generated:  0.60 s
# Raster generated:  0.60 s
# Raster generated:  0.57 s
# Raster generated:  0.58 s
# Raster generated:  0.56 s
# Raster generated:  0.85 s
# Raster generated:  0.84 s
# Raster generated:  0.86 s
# Raster generated:  1.01 s
# Raster generated:  1.00 s
# Raster generated:  0.87 s
# Raster generated:  0.90 s
# Raster generated:  1.01 s
# Raster generated:  1.00 s
# Raster generated:  1.01 s
# Raster generated:  2.26 s
# Raster generated:  0.58 s
# Raster generated:  2.94 s
# Raster generated:  0.60 s
# Raster generated:  3.73 s
# Raster generated:  0.60 s
# Raster generated:  4.71 s
# Raster generated:  0.60 s
# Raster generated:  0.79 s
# Raster generated:  0.88 s
# Raster generated:  0.89 s
# Raster generated:  0.87 s
# Raster generated:  0.88 s
# Raster generated:  0.88 s

# %%
c_etl.missing_synapses_analysis(a_hex0)

# %%
c_etl.flatspace_videos(a_hexO1)
