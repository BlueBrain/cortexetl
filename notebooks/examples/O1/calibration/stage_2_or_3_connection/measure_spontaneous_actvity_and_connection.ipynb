# %%
import sys
sys.path.append('../../../../..')
import cortexetl as c_etl

# %%
# ma = c_etl.analysis_initial_processing("stage_2_or_3_connection_x.yaml", loglevel="ERROR") #
# ma = c_etl.analysis_initial_processing("connectome_rewiring_calibration_example.yaml") # loglevel="ERROR"
# ma = c_etl.analysis_initial_processing('/gpfs/bbp.cscs.ch/project/proj83/home/isbister/physiology_2023/cortexetl.configs/post_physiology_2023/campaigns/schneider_mizell/0_recalibration/0_0_recalibration_6thIter_20_3_24.yaml') # loglevel="ERROR"
ma = c_etl.analysis_initial_processing('/gpfs/bbp.cscs.ch/project/proj83/home/isbister/physiology_2023/cortexetl.configs/post_physiology_2023/campaigns/schneider_mizell/1_whisker_deflections/1_0_whisker_deflections_test_28_3_24.yaml')
a_hex0 = ma.hex0_spikes


# a_hexO1 = ma.hex_O1_spikes
# Out:
# 2024-03-28 16:00:57,616 INFO blueetl.analysis: MultiAnalyzer configuration: /gpfs/bbp.cscs.ch/project/proj83/home/isbister/physiology_2023/cortexetl.configs/post_physiology_2023/campaigns/schneider_mizell/1_whisker_deflections/1_0_whisker_deflections_test_28_3_24.yaml
# 2024-03-28 16:00:57,702 INFO blueetl.store.base: Using class ParquetStore with basedir /gpfs/bbp.cscs.ch/project/proj83/home/isbister/post_physiology_2023/cortex_etl_output/campaigns/schneider_mizell/1_whisker_deflections/1_0_whisker_deflections_test_28_3_24/hex0_spikes/repo
# 2024-03-28 16:00:57,703 INFO blueetl.store.base: Using class ParquetStore with basedir /gpfs/bbp.cscs.ch/project/proj83/home/isbister/post_physiology_2023/cortex_etl_output/campaigns/schneider_mizell/1_whisker_deflections/1_0_whisker_deflections_test_28_3_24/hex0_spikes/features
# ...

# %%
c_etl.post_analysis(a_hex0)
# Out:
# [Parallel(n_jobs=36)]: Using backend LokyBackend with 36 concurrent workers.
# 2024-03-28 16:01:01,616 INFO blueetl.parallel: Considering 2 rows for columns ['simulation_id', 'circuit_id']
# 2024-03-28 16:01:01,619 INFO blueetl.parallel: Tasks to be executed: 2
# ----- Custom post analysis -----
# Custom post analysis:  1
# [1.65617754e-04 2.64988407e-04 1.32494203e-04 2.31864856e-04
#  1.98741305e-04 2.64988407e-04 9.93706525e-05 1.98741305e-04
#  1.98741305e-04 3.97482610e-04 6.95594568e-04 1.19244783e-03
#  2.38489566e-03 2.41801921e-03 2.31864856e-03 2.05366015e-03
#  1.68930109e-03 1.25869493e-03 1.25869493e-03 1.09307718e-03
#  9.27459424e-04 6.62471017e-04 6.95594568e-04 7.28718119e-04
#  5.63100364e-04 6.62471017e-04 4.30606161e-04 6.29347466e-04
#  4.30606161e-04 2.31864856e-04 6.62471017e-04 4.96853263e-04
#  5.96223915e-04 3.64359059e-04 4.63729712e-04 4.96853263e-04
#  4.30606161e-04 4.96853263e-04 5.96223915e-04 2.98111958e-04
# ...

# %%
c_etl.plot_multi_sim_analysis(a_hex0)

# %%
c_etl.plot_rasters(a_hex0)
# Out:
# [Parallel(n_jobs=36)]: Using backend LokyBackend with 36 concurrent workers.
# 2024-03-28 16:01:07,467 INFO blueetl.parallel: Considering 2 rows for columns ['simulation_id', 'circuit_id']
# 2024-03-28 16:01:07,469 INFO blueetl.parallel: Tasks to be executed: 2
# ----- Plot rasters, window: conn_spont -----
# [Parallel(n_jobs=36)]: Done   2 out of   2 | elapsed:    3.8s finished
# [Parallel(n_jobs=36)]: Using backend LokyBackend with 36 concurrent workers.
# 2024-03-28 16:01:11,376 INFO blueetl.parallel: Considering 2 rows for columns ['simulation_id', 'circuit_id']
# 2024-03-28 16:01:11,379 INFO blueetl.parallel: Tasks to be executed: 2
# [Parallel(n_jobs=36)]: Done   2 out of   2 | elapsed:    2.6s finished
# [Parallel(n_jobs=36)]: Using backend LokyBackend with 36 concurrent workers.
# 2024-03-28 16:01:14,059 INFO blueetl.parallel: Considering 2 rows for columns ['simulation_id', 'circuit_id']
# 2024-03-28 16:01:14,061 INFO blueetl.parallel: Tasks to be executed: 2
# ...

# %%
c_etl.extract_fr_df(a_hex0)

# %%
c_etl.missing_synapses_analysis(a_hex0)

# %%
c_etl.flatspace_videos(a_hexO1)
